# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.rand(1000)
plt.hist(x,100)
plt.xlabel('value of x +/- 0.005')
plt.ylabel('number of x values')
plt.savefig('histogram.png')
