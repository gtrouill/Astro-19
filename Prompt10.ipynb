# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
myrng = np.random.default_rng(123456790)
x = myrng.random(1000)
plt.hist(x,100)
plt.xlabel('value of number +/- 0.05')
plt.ylabel('number of values')
plt.savefig('rnghist.png')
